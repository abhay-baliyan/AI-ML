# %% [markdown]
# #  importing all important libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.cluster import KMeans

# %% [markdown]
# #  importing the dataset

# %%
p=pd.read_csv(r"cardio_train.csv",sep=';')
p
# Out:
#           id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0  18393       2     168    62.0    110     80            1     1
# 1          1  20228       1     156    85.0    140     90            3     1
# 2          2  18857       1     165    64.0    130     70            3     1
# 3          3  17623       2     169    82.0    150    100            1     1
# 4          4  17474       1     156    56.0    100     60            1     1
# ...      ...    ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993  19240       2     168    76.0    120     80            1     1
# 69996  99995  22601       1     158   126.0    140     90            2     2
# 69997  99996  19066       2     183   105.0    180     90            3     1
# 69998  99998  22431       1     163    72.0    135     80            1     2
# 69999  99999  20540       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
p.shape
# Out:
# (70000, 13)

# %%
p.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
p.describe()
# Out:
#                  id           age        gender        height        weight  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean   49972.419900  19468.865814      1.349571    164.359229     74.205690
# std    28851.302323   2467.251667      0.476838      8.210126     14.395757
# min        0.000000  10798.000000      1.000000     55.000000     10.000000
# 25%    25006.750000  17664.000000      1.000000    159.000000     65.000000
# 50%    50001.500000  19703.000000      1.000000    165.000000     72.000000
# 75%    74889.250000  21327.000000      2.000000    170.000000     82.000000
# max    99999.000000  23713.000000      2.000000    250.000000    200.000000
#
#               ap_hi         ap_lo   cholesterol          gluc         smoke  \
# count  70000.000000  70000.000000  70000.000000  70000.000000  70000.000000
# mean     128.817286     96.630414      1.366871      1.226457      0.088129
# ...

# %%
p['age']=(p['age']//365)
p['age']
# Out:
# 0        50
# 1        55
# 2        51
# 3        48
# 4        47
#          ..
# 69995    52
# 69996    61
# 69997    52
# 69998    61
# 69999    56
# Name: age, Length: 70000, dtype: int64

# %% [markdown]
# # line charts

# %%
x=p.iloc[:,1:]
x.plot.line()
# Out:
# <Axes: >

# %% [markdown]
# # bar graphs of different features with respect to cardio

# %%
x1=p.iloc[:,[0]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[1]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[2]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[3]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[4]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[5]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[6]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[7]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[8]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[9]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[10]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[11]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %%
x1=p.iloc[:,[12]]
y1=p.iloc[:,[-1]]
plt.scatter(x1,y1)

# %% [markdown]
# # bar graphs

# %%
p['cardio'].value_counts()
# Out:
# 0    35021
# 1    34979
# Name: cardio, dtype: int64

# %%
p0 = p[p['cardio'] == False]
p0
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       2     168    62.0    110     80            1     1
# 4          4   47       1     156    56.0    100     60            1     1
# 5          8   60       1     151    67.0    120     80            2     2
# 6          9   60       1     157    93.0    130     80            3     1
# 8         13   48       1     158    71.0    110     70            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69987  99979   51       1     151    49.0    120     80            1     1
# 69988  99981   60       1     160    59.0    110     70            1     1
# 69991  99988   56       1     159    72.0    130     90            2     2
# 69995  99993   52       2     168    76.0    120     80            1     1
# 69999  99999   56       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio
# ...

# %%
p1 = p[p['cardio'] == True]
p1
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 1          1   55       1     156    85.0    140     90            3     1
# 2          2   51       1     165    64.0    130     70            3     1
# 3          3   48       2     169    82.0    150    100            1     1
# 7         12   61       2     178    95.0    130     90            3     3
# 15        24   45       2     172   112.0    120     80            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69993  99991   53       1     172    70.0    130     90            1     1
# 69994  99992   57       1     165    80.0    150     80            1     1
# 69996  99995   61       1     158   126.0    140     90            2     2
# 69997  99996   52       2     183   105.0    180     90            3     1
# 69998  99998   61       1     163    72.0    135     80            1     2
#
#        smoke  alco  active  cardio
# ...

# %%
sns.countplot(x=p['cardio'])
# Out:
# <Axes: xlabel='cardio', ylabel='count'>

# %%
p['age']
# Out:
# 0        50
# 1        55
# 2        51
# 3        48
# 4        47
#          ..
# 69995    52
# 69996    61
# 69997    52
# 69998    61
# 69999    56
# Name: age, Length: 70000, dtype: int64

# %%
sns.countplot(x='age', hue='cardio', data = p);

# %% [markdown]
# # train-test split

# %%
x=p.iloc[:,:-1]
y=p.iloc[:,[-1]]
xtrain,xtest,ytrain,ytest=train_test_split(x,y,train_size=0.8)

# %% [markdown]
# # SVM classifier model

# %%
model1=SVC(kernel='linear')
model1.fit(xtrain,ytrain)
# Out:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(kernel='linear')

# %%
model1.predict(xtest)
# Out:
# array([0, 1, 0, ..., 0, 0, 1], dtype=int64)

# %%
model1.score(xtrain,ytrain)
# Out:
# 0.7170535714285714

# %%
model1.score(xtest,ytest)
# Out:
# 0.7196428571428571

# %% [markdown]
# # KNN classifier model

# %%
model2=KNeighborsClassifier()
model2.fit(xtrain,ytrain)
# Out:
# D:\anaconda\Lib\site-packages\sklearn\neighbors\_classification.py:228: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
model2.predict(xtest)
# Out:
# array([0, 1, 1, ..., 1, 1, 0], dtype=int64)

# %%
model2.score(xtrain,ytrain)
# Out:
# 0.7675357142857143

# %%
model2.score(xtest,ytest)
# Out:
# 0.6391428571428571

# %% [markdown]
# # decision tree classifier model

# %%
model3=DecisionTreeClassifier()
model3.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %%
model3.predict(xtest)
# Out:
# array([1, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
model3.score(xtrain,ytrain)
# Out:
# 1.0

# %%
model3.score(xtest,ytest)
# Out:
# 0.6345

# %%
tree.plot_tree(model3)
# Out:
# [Text(0.6028474930790512, 0.99, 'x[5] <= 129.5\ngini = 0.5\nsamples = 56000\nvalue = [28051, 27949]'),
#  Text(0.38772721552586376, 0.97, 'x[1] <= 54.5\ngini = 0.434\nsamples = 33078\nvalue = [22549, 10529]'),
#  Text(0.23174524955631384, 0.95, 'x[7] <= 2.5\ngini = 0.365\nsamples = 20549\nvalue = [15608, 4941]'),
#  Text(0.12468883049684373, 0.93, 'x[1] <= 44.5\ngini = 0.349\nsamples = 19655\nvalue = [15224, 4431]'),
#  Text(0.048450888436772324, 0.91, 'x[7] <= 1.5\ngini = 0.25\nsamples = 6104\nvalue = [5209, 895]'),
#  Text(0.030515161071239923, 0.89, 'x[5] <= 114.5\ngini = 0.23\nsamples = 5499\nvalue = [4771, 728]'),
#  Text(0.014393228134014446, 0.87, 'x[8] <= 1.5\ngini = 0.164\nsamples = 2336\nvalue = [2125, 211]'),
#  Text(0.007897856713198086, 0.85, 'x[5] <= 109.5\ngini = 0.154\nsamples = 2209\nvalue = [2023, 186]'),
#  Text(0.0027637528512245687, 0.83, 'x[6] <= 77.5\ngini = 0.107\nsamples = 755\nvalue = [712, 43]'),
# ...

# %% [markdown]
# # logistic regression model

# %%
model4=LogisticRegression()
model4.fit(xtrain,ytrain)
# Out:
# D:\anaconda\Lib\site-packages\sklearn\utils\validation.py:1184: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# D:\anaconda\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
model4.predict(xtest)
# Out:
# array([0, 1, 1, ..., 0, 1, 0], dtype=int64)

# %%
model4.score(xtrain,ytrain)
# Out:
# 0.6956785714285715

# %%
model4.score(xtest,ytest)
# Out:
# 0.6913571428571429

# %% [markdown]
# # random forest classifier model

# %%
rfmodel=RandomForestClassifier()
rfmodel.fit(xtrain,ytrain)
# Out:
# D:\anaconda\Lib\site-packages\sklearn\base.py:1151: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
rfmodel.predict(xtest)
# Out:
# array([0, 1, 0, ..., 0, 0, 0], dtype=int64)

# %%
rfmodel.score(xtrain, ytrain)
# Out:
# 0.9999464285714286

# %%
rfmodel.score(xtest,ytest)
# Out:
# 0.7215714285714285

# %% [markdown]
# # clustering

# %%
kmeans=KMeans(n_clusters=5)
kmeans.fit(p)
kmeans.cluster_centers_
# Out:
# D:\anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# array([[5.02786229e+04, 5.28672232e+01, 1.34068208e+00, 1.64334118e+02,
#         7.43537743e+01, 1.28317209e+02, 9.62755422e+01, 1.35923231e+00,
#         1.22424372e+00, 8.40468037e-02, 5.25827626e-02, 7.99728881e-01,
#         5.02925228e-01],
#        [1.00666294e+04, 5.28388535e+01, 1.34713376e+00, 1.64372045e+02,
#         7.42175513e+01, 1.27798938e+02, 9.68307856e+01, 1.36270347e+00,
#         1.22236377e+00, 9.01627742e-02, 5.32200991e-02, 8.00566171e-01,
#         4.96178344e-01],
#        [9.00886034e+04, 5.28604971e+01, 1.35995362e+00, 1.64388724e+02,
#         7.41653815e+01, 1.27107689e+02, 9.64252482e+01, 1.37604174e+00,
#         1.22719038e+00, 8.92093630e-02, 5.53663309e-02, 8.02884267e-01,
# ...

# %%
kmeans.labels_
# Out:
# array([1, 1, 1, ..., 2, 2, 2])

# %%
p["Cluster Group"]=kmeans.labels_
p
# Out:
#           id  age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  \
# 0          0   50       2     168    62.0    110     80            1     1
# 1          1   55       1     156    85.0    140     90            3     1
# 2          2   51       1     165    64.0    130     70            3     1
# 3          3   48       2     169    82.0    150    100            1     1
# 4          4   47       1     156    56.0    100     60            1     1
# ...      ...  ...     ...     ...     ...    ...    ...          ...   ...
# 69995  99993   52       2     168    76.0    120     80            1     1
# 69996  99995   61       1     158   126.0    140     90            2     2
# 69997  99996   52       2     183   105.0    180     90            3     1
# 69998  99998   61       1     163    72.0    135     80            1     2
# 69999  99999   56       1     170    72.0    120     80            2     1
#
#        smoke  alco  active  cardio  Cluster Group
# ...

# %%
p["Cluster Group"].value_counts()
# Out:
# 1    14115
# 3    14042
# 0    14022
# 4    14005
# 2    13816
# Name: Cluster Group, dtype: int64

# %%
sns.scatterplot(data=x)
# Out:
# <Axes: >

# %% [markdown]
# # correlation matrix

# %%
p.corr()
sns.set(rc = {'figure.figsize':(16,8)})
sns.heatmap(p.corr(), annot = True)
# Out:
# <Axes: >

# %% [markdown]
# # as we can see from the above models, we should use random forest or decision tree model as they both have best accuracy score than compared to other models to build our model for heart disease detection
